# %% [markdown]
# **Exploratory Data Analysis On Terrorism Dataset**

# %% [markdown]
# **Summary :**
#
# The project embarked on a comprehensive analysis of the Global Terrorism Database (GTD), a repository of over 180,000 terrorist incidents spanning four decades from 1970 to 2017. This open-source database, managed by the National Consortium for the Study of Terrorism and Responses to Terrorism (START) at the University of Maryland, offers a wealth of information on terrorism's patterns, impacts, and dynamics. The analysis was guided by a set of business objectives, aiming to extract insights that would contribute to informed decision-making, enhanced security measures, and public awareness efforts.
#
# The project involved a series of systematic steps, including importing important libraries, loading and understanding the dataset's structure, identifying key variables, and addressing data quality concerns such as duplicate values and missing data. Data wrangling techniques were employed to refine the dataset, followed by exploratory data visualization using line charts, pie charts, pair plots, and horizontal bar charts to uncover trends, correlations, and distributions.
#
# Key insights and findings emerged from the analysis:
#
# Temporal Trends: An exploration of temporal trends revealed cyclical patterns, with a surge in incidents around 2014 possibly linked to geopolitical events. Recent years displayed a decline, potentially indicating the effectiveness of counterterrorism measures.
#
# Geographical Patterns: The analysis highlighted regions like the Middle East & North Africa and South Asia as hotspots for terrorist incidents, underscoring the need for targeted security measures.
#
# Attack Tactics and Targets: Insights into prevalent attack tactics (e.g., bombings/explosions) and target types (e.g., private citizens, military) provided a nuanced understanding of terrorists' methods and motivations.
#
# Success Rates and Correlations: The analysis revealed a relatively high success rate of attacks and identified variables with strong correlations, shedding light on underlying dynamics.
#
# Based on these insights, a set of strategic recommendations was devised to achieve the business objectives:
#
# Strategic Security Measures: Deploy enhanced security measures in high-incident regions, addressing prevalent attack tactics and vulnerabilities in target types.
#
# Global Collaboration: Foster collaboration among international organizations to counter regional and city-specific terrorism concentrations through information sharing and coordinated efforts.
#
# Targeted Counter-Radicalization: Design tailored initiatives to counter radicalization efforts of active terrorist groups, discouraging individuals from joining their ranks.
#
# Public Awareness Campaigns: Utilize insights to create impactful campaigns that educate the public about terrorism's complexities and the ongoing efforts to combat it.
#
# Policy Refinement: Collaborate with policymakers to formulate evidence-based counterterrorism policies, considering vulnerabilities and refining strategies.
#
# Continuous Evaluation and Adaptation: Establish mechanisms to continuously evaluate and adapt counterterrorism efforts, leveraging feedback for strategy refinement.

# %% [markdown]
# *Problem Statement:*
#
# 1. What are the temporal trends in global terrorism over the last four decades?
# 2. Which region have experienced the highest frequency of terrorist attacks?
# 3. Which countries have experienced the highest frequency of terrorist attacks?
# 4. Which city have experienced the highest frequency of terrorist attacks?
# 5. What are the most common types of terrorist tactics employed during the studied period?
# 6. Are there any seasonal or cyclical patterns in terrorist activity?
# 7. How have terrorist attack patterns evolved over time in different regions?
# 8. Analyze the occurrence of different attack types across various regions to uncover patterns in the geographical distribution of terrorist tactics?
# 9. What are the primary target types of terrorist attacks recorded?
# 10. What are the most frequent weapons used in terrorist attacks?
# 11. Is there a correlation between the target type and the attack type?
# 12. To identify and analyze the terrorist group with the highest contribution in terrorist?
# 13. What is the proportion of successful terrorist attacks compared to failed ones using the 'success' variable?

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\ayush\Downloads\Global Terrorism - START data\globalterrorismdb_0718dist.csv', encoding='latin-1')
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_21872\2134277329.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\ayush\Downloads\Global Terrorism - START data\globalterrorismdb_0718dist.csv', encoding='latin-1')

# %%
df
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# 0            58  Dominican Republic       2  ...      NaN
# 1           130              Mexico       1  ...      NaN
# 2           160         Philippines       5  ...      NaN
# 3            78              Greece       8  ...      NaN
# 4           101               Japan       4  ...      NaN
# ...         ...                 ...     ...  ...      ...
# 181686      182             Somalia      11  ...      NaN
# 181687      200               Syria      10  ...      NaN
# 181688      160         Philippines       5  ...      NaN
# 181689       92               India       6  ...      NaN
# 181690      160         Philippines       5  ...      NaN
#
#                                                    scite1  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0                           PGIS        0         0        0       0      NaN
# 1                           PGIS        0         1        1       1      NaN
# 2                           PGIS       -9        -9        1       1      NaN
# 3                           PGIS       -9        -9        1       1      NaN
# 4                           PGIS       -9        -9        1       1      NaN
# ...                          ...      ...       ...      ...     ...      ...
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [181691 rows x 135 columns]

# %%
df.head(10)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
# 5  197001010002   1970       1     1        NaN         0        NaN      217
# 6  197001020001   1970       1     2        NaN         0        NaN      218
# 7  197001020002   1970       1     2        NaN         0        NaN      217
# 8  197001020003   1970       1     2        NaN         0        NaN      217
# 9  197001030001   1970       1     3        NaN         0        NaN      217
#
#           country_txt  region  ...  \
# 0  Dominican Republic       2  ...
# 1              Mexico       1  ...
# 2         Philippines       5  ...
# 3              Greece       8  ...
# 4               Japan       4  ...
# 5       United States       1  ...
# 6             Uruguay       3  ...
# 7       United States       1  ...
# 8       United States       1  ...
# 9       United States       1  ...
#
#                                             addnotes  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  The Cairo Chief of Police, William Petersen, r...
# 6                                                NaN
# 7  Damages were estimated to be between $20,000-$...
# 8  The New Years Gang issue a communiqué to a loc...
# 9  Karl Armstrong's girlfriend, Lynn Schultz, dro...
#
#                                               scite1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  "Police Chief Quits," Washington Post, January...
# 6                                                NaN
# 7  Committee on Government Operations United Stat...
# 8  Tom Bates, "Rads: The 1970 Bombing of the Army...
# 9  Committee on Government Operations United Stat...
#
#                                               scite2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  "Cairo Police Chief Quits; Decries Local 'Mili...
# 6                                                NaN
# 7  Christopher Hewitt, "Political Violence and Te...
# 8  David Newman, Sandra Sutherland, and Jon Stewa...
# 9  Tom Bates, "Rads: The 1970 Bombing of the Army...
#
#                                               scite3        dbsource  INT_LOG  \
# 0                                                NaN            PGIS        0
# 1                                                NaN            PGIS        0
# 2                                                NaN            PGIS       -9
# 3                                                NaN            PGIS       -9
# 4                                                NaN            PGIS       -9
# 5  Christopher Hewitt, "Political Violence and Te...  Hewitt Project       -9
# 6                                                NaN            PGIS        0
# 7                                                NaN  Hewitt Project       -9
# 8  The Wisconsin Cartographers' Guild, "Wisconsin...  Hewitt Project        0
# 9  David Newman, Sandra Sutherland, and Jon Stewa...  Hewitt Project        0
#
#    INT_IDEO INT_MISC INT_ANY  related
# 0         0        0       0      NaN
# 1         1        1       1      NaN
# 2        -9        1       1      NaN
# 3        -9        1       1      NaN
# 4        -9        1       1      NaN
# 5        -9        0      -9      NaN
# 6         0        0       0      NaN
# 7        -9        0      -9      NaN
# 8         0        0       0      NaN
# 9         0        0       0      NaN
#
# [10 rows x 135 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# 0            58  Dominican Republic       2  ...      NaN
# 1           130              Mexico       1  ...      NaN
# 2           160         Philippines       5  ...      NaN
# 3            78              Greece       8  ...      NaN
# 4           101               Japan       4  ...      NaN
# ...         ...                 ...     ...  ...      ...
# 181686      182             Somalia      11  ...      NaN
# 181687      200               Syria      10  ...      NaN
# 181688      160         Philippines       5  ...      NaN
# 181689       92               India       6  ...      NaN
# 181690      160         Philippines       5  ...      NaN
#
#                                                    scite1  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0                           PGIS        0         0        0       0      NaN
# 1                           PGIS        0         1        1       1      NaN
# 2                           PGIS       -9        -9        1       1      NaN
# 3                           PGIS       -9        -9        1       1      NaN
# 4                           PGIS       -9        -9        1       1      NaN
# ...                          ...      ...       ...      ...     ...      ...
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [181691 rows x 135 columns]>

# %%
df.describe().T
# Out:
#               count          mean           std           min           25%  \
# eventid    181691.0  2.002705e+11  1.325957e+09  1.970000e+11  1.991021e+11
# iyear      181691.0  2.002639e+03  1.325943e+01  1.970000e+03  1.991000e+03
# imonth     181691.0  6.467277e+00  3.388303e+00  0.000000e+00  4.000000e+00
# iday       181691.0  1.550564e+01  8.814045e+00  0.000000e+00  8.000000e+00
# extended   181691.0  4.534622e-02  2.080629e-01  0.000000e+00  0.000000e+00
# ...             ...           ...           ...           ...           ...
# nreleased   10400.0 -2.901827e+01  6.572012e+01 -9.900000e+01 -9.900000e+01
# INT_LOG    181691.0 -4.543731e+00  4.543547e+00 -9.000000e+00 -9.000000e+00
# INT_IDEO   181691.0 -4.464398e+00  4.637152e+00 -9.000000e+00 -9.000000e+00
# INT_MISC   181691.0  9.000996e-02  5.684573e-01 -9.000000e+00  0.000000e+00
# INT_ANY    181691.0 -3.945952e+00  4.691325e+00 -9.000000e+00 -9.000000e+00
#
#                     50%           75%           max
# eventid    2.009022e+11  2.014081e+11  2.017123e+11
# iyear      2.009000e+03  2.014000e+03  2.017000e+03
# imonth     6.000000e+00  9.000000e+00  1.200000e+01
# iday       1.500000e+01  2.300000e+01  3.100000e+01
# extended   0.000000e+00  0.000000e+00  1.000000e+00
# ...                 ...           ...           ...
# nreleased  0.000000e+00  1.000000e+00  2.769000e+03
# INT_LOG   -9.000000e+00  0.000000e+00  1.000000e+00
# INT_IDEO  -9.000000e+00  0.000000e+00  1.000000e+00
# INT_MISC   0.000000e+00  0.000000e+00  1.000000e+00
# INT_ANY    0.000000e+00  0.000000e+00  1.000000e+00
#
# [77 rows x 8 columns]

# %%
df.shape
# Out:
# (181691, 135)

# %%
Duplicate_values=df[df.duplicated()].sum()

# %%
Duplicate_values[:51]
# Out:
# eventid               0
# iyear                 0
# imonth                0
# iday                  0
# approxdate            0
# extended              0
# resolution            0
# country               0
# country_txt           0
# region                0
# region_txt            0
# provstate             0
# city                  0
# latitude            0.0
# longitude           0.0
# specificity         0.0
# vicinity              0
# location              0
# summary               0
# crit1                 0
# crit2                 0
# crit3                 0
# doubtterr           0.0
# alternative         0.0
# alternative_txt       0
# multiple            0.0
# success               0
# suicide               0
# attacktype1           0
# attacktype1_txt       0
# attacktype2         0.0
# attacktype2_txt       0
# attacktype3         0.0
# attacktype3_txt       0
# targtype1             0
# targtype1_txt         0
# targsubtype1        0.0
# targsubtype1_txt      0
# corp1                 0
# target1               0
# natlty1             0.0
# natlty1_txt           0
# targtype2           0.0
# targtype2_txt         0
# targsubtype2        0.0
# targsubtype2_txt      0
# corp2                 0
# target2               0
# natlty2             0.0
# natlty2_txt           0
# targtype3           0.0
# dtype: object

# %%
Duplicate_values[51:101]
# Out:
# targtype3_txt         0
# targsubtype3        0.0
# targsubtype3_txt      0
# corp3                 0
# target3               0
# natlty3             0.0
# natlty3_txt           0
# gname                 0
# gsubname              0
# gname2                0
# gsubname2             0
# gname3                0
# gsubname3             0
# motive                0
# guncertain1         0.0
# guncertain2         0.0
# guncertain3         0.0
# individual            0
# nperps              0.0
# nperpcap            0.0
# claimed             0.0
# claimmode           0.0
# claimmode_txt         0
# claim2              0.0
# claimmode2          0.0
# claimmode2_txt        0
# claim3              0.0
# claimmode3          0.0
# claimmode3_txt        0
# compclaim           0.0
# weaptype1             0
# weaptype1_txt         0
# weapsubtype1        0.0
# weapsubtype1_txt      0
# weaptype2           0.0
# weaptype2_txt         0
# weapsubtype2        0.0
# weapsubtype2_txt      0
# weaptype3           0.0
# weaptype3_txt         0
# weapsubtype3        0.0
# weapsubtype3_txt      0
# weaptype4           0.0
# weaptype4_txt         0
# weapsubtype4        0.0
# weapsubtype4_txt      0
# weapdetail            0
# nkill               0.0
# nkillus             0.0
# nkillter            0.0
# dtype: object

# %%
Duplicate_values[101:]
# Out:
# nwound                0.0
# nwoundus              0.0
# nwoundte              0.0
# property                0
# propextent            0.0
# propextent_txt          0
# propvalue             0.0
# propcomment             0
# ishostkid             0.0
# nhostkid              0.0
# nhostkidus            0.0
# nhours                0.0
# ndays                 0.0
# divert                  0
# kidhijcountry           0
# ransom                0.0
# ransomamt             0.0
# ransomamtus           0.0
# ransompaid            0.0
# ransompaidus          0.0
# ransomnote              0
# hostkidoutcome        0.0
# hostkidoutcome_txt      0
# nreleased             0.0
# addnotes                0
# scite1                  0
# scite2                  0
# scite3                  0
# dbsource                0
# INT_LOG                 0
# INT_IDEO                0
# INT_MISC                0
# INT_ANY                 0
# related                 0
# dtype: object

# %%
Null_values=df.isna().sum()

# %%
Null_values[:51]
# Out:
# eventid                  0
# iyear                    0
# imonth                   0
# iday                     0
# approxdate          172452
# extended                 0
# resolution          179471
# country                  0
# country_txt              0
# region                   0
# region_txt               0
# provstate              421
# city                   435
# latitude              4556
# longitude             4557
# specificity              6
# vicinity                 0
# location            126196
# summary              66129
# crit1                    0
# crit2                    0
# crit3                    0
# doubtterr                1
# alternative         152680
# alternative_txt     152680
# multiple                 1
# success                  0
# suicide                  0
# attacktype1              0
# attacktype1_txt          0
# attacktype2         175377
# attacktype2_txt     175377
# attacktype3         181263
# attacktype3_txt     181263
# targtype1                0
# targtype1_txt            0
# targsubtype1         10373
# targsubtype1_txt     10373
# corp1                42552
# target1                638
# natlty1               1559
# natlty1_txt           1559
# targtype2           170547
# targtype2_txt       170547
# targsubtype2        171006
# targsubtype2_txt    171006
# corp2               171574
# target2             170671
# natlty2             170863
# natlty2_txt         170863
# targtype3           180515
# dtype: int64

# %%
Null_values[51:101]
# Out:
# targtype3_txt       180515
# targsubtype3        180594
# targsubtype3_txt    180594
# corp3               180665
# target3             180516
# natlty3             180544
# natlty3_txt         180544
# gname                    0
# gsubname            175801
# gname2              179678
# gsubname2           181531
# gname3              181367
# gsubname3           181671
# motive              131130
# guncertain1            380
# guncertain2         179736
# guncertain3         181371
# individual               0
# nperps               71115
# nperpcap             69489
# claimed              66120
# claimmode           162608
# claimmode_txt       162608
# claim2              179801
# claimmode2          181075
# claimmode2_txt      181075
# claim3              181373
# claimmode3          181558
# claimmode3_txt      181558
# compclaim           176852
# weaptype1                0
# weaptype1_txt            0
# weapsubtype1         20768
# weapsubtype1_txt     20768
# weaptype2           168564
# weaptype2_txt       168564
# weapsubtype2        170149
# weapsubtype2_txt    170149
# weaptype3           179828
# weaptype3_txt       179828
# weapsubtype3        179998
# weapsubtype3_txt    179998
# weaptype4           181618
# weaptype4_txt       181618
# weapsubtype4        181621
# weapsubtype4_txt    181621
# weapdetail           67670
# nkill                10313
# nkillus              64446
# nkillter             66958
# dtype: int64

# %%
Null_values[101:]
# Out:
# nwound                 16311
# nwoundus               64702
# nwoundte               69143
# property                   0
# propextent            117626
# propextent_txt        117626
# propvalue             142702
# propcomment           123732
# ishostkid                178
# nhostkid              168119
# nhostkidus            168174
# nhours                177628
# ndays                 173567
# divert                181367
# kidhijcountry         178386
# ransom                104310
# ransomamt             180341
# ransomamtus           181128
# ransompaid            180917
# ransompaidus          181139
# ransomnote            181179
# hostkidoutcome        170700
# hostkidoutcome_txt    170700
# nreleased             171291
# addnotes              153402
# scite1                 66191
# scite2                104758
# scite3                138175
# dbsource                   0
# INT_LOG                    0
# INT_IDEO                   0
# INT_MISC                   0
# INT_ANY                    0
# related               156653
# dtype: int64

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(df.isna())
plt.title('Null Values Heatmap')
plt.show()

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.describe(include='all')
# Out:
#              eventid          iyear         imonth           iday  \
# count   1.816910e+05  181691.000000  181691.000000  181691.000000
# unique           NaN            NaN            NaN            NaN
# top              NaN            NaN            NaN            NaN
# freq             NaN            NaN            NaN            NaN
# mean    2.002705e+11    2002.638997       6.467277      15.505644
# std     1.325957e+09      13.259430       3.388303       8.814045
# min     1.970000e+11    1970.000000       0.000000       0.000000
# 25%     1.991021e+11    1991.000000       4.000000       8.000000
# 50%     2.009022e+11    2009.000000       6.000000      15.000000
# 75%     2.014081e+11    2014.000000       9.000000      23.000000
# max     2.017123e+11    2017.000000      12.000000      31.000000
#
#                    approxdate       extended resolution        country  \
# count                    9239  181691.000000       2220  181691.000000
# unique                   2244            NaN       1859            NaN
# top     September 18-24, 2016            NaN   8/4/1998            NaN
# freq                      101            NaN         18            NaN
# mean                      NaN       0.045346        NaN     131.968501
# std                       NaN       0.208063        NaN     112.414535
# min                       NaN       0.000000        NaN       4.000000
# 25%                       NaN       0.000000        NaN      78.000000
# 50%                       NaN       0.000000        NaN      98.000000
# 75%                       NaN       0.000000        NaN     160.000000
# max                       NaN       1.000000        NaN    1004.000000
#
#        country_txt         region  ...  \
# count       181691  181691.000000  ...
# unique         205            NaN  ...
# top           Iraq            NaN  ...
# freq         24636            NaN  ...
# mean           NaN       7.160938  ...
# std            NaN       2.933408  ...
# min            NaN       1.000000  ...
# 25%            NaN       5.000000  ...
# 50%            NaN       6.000000  ...
# 75%            NaN      10.000000  ...
# max            NaN      12.000000  ...
#
#                                                  addnotes  \
# count                                               28289
# unique                                              15429
# top     Casualty numbers for this incident conflict ac...
# freq                                                 1607
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                    scite1  \
# count                                              115500
# unique                                              83988
# top     Committee on Government Operations United Stat...
# freq                                                  205
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                    scite2  \
# count                                               76933
# unique                                              62263
# top     Christopher Hewitt, "Political Violence and Te...
# freq                                                  134
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                    scite3  \
# count                                               43516
# unique                                              36090
# top     Christopher Hewitt, "Political Violence and Te...
# freq                                                  139
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                         dbsource        INT_LOG       INT_IDEO       INT_MISC  \
# count                     181691  181691.000000  181691.000000  181691.000000
# unique                        26            NaN            NaN            NaN
# top     START Primary Collection            NaN            NaN            NaN
# freq                       78002            NaN            NaN            NaN
# mean                         NaN      -4.543731      -4.464398       0.090010
# std                          NaN       4.543547       4.637152       0.568457
# min                          NaN      -9.000000      -9.000000      -9.000000
# 25%                          NaN      -9.000000      -9.000000       0.000000
# 50%                          NaN      -9.000000      -9.000000       0.000000
# 75%                          NaN       0.000000       0.000000       0.000000
# max                          NaN       1.000000       1.000000       1.000000
#
#               INT_ANY                                            related
# count   181691.000000                                              25038
# unique            NaN                                              14306
# top               NaN  201612010023, 201612010024, 201612010025, 2016...
# freq              NaN                                                 80
# mean        -3.945952                                                NaN
# std          4.691325                                                NaN
# min         -9.000000                                                NaN
# 25%         -9.000000                                                NaN
# 50%          0.000000                                                NaN
# 75%          0.000000                                                NaN
# max          1.000000                                                NaN
#
# [11 rows x 135 columns]

# %% [markdown]
# A short description of some important variables in the Gterrorism_df dataset:
#
# eventid: Unique identifier for each terrorism event.
#
# iyear: Year of the incident.
#
# imonth: Month of the incident.
#
# iday: Day of the incident.
#
# country_txt: Name of the country where the incident occurred.
#
# region_txt: Name of the region where the incident occurred.
#
# city: Name of the city where the incident occurred.
#
# latitude: Latitude coordinate of the incident location.
#
# longitude: Longitude coordinate of the incident location.
#
# gname: Name of the terrorist group responsible for the incident.
#
# nkill: Number of people killed in the incident.
#
# nwound: Number of people wounded in the incident.
#
# weaptype1_txt: Type of weapon used in the incident.
#
# targtype1_txt: Type of target/victim of the attack.
#
# 'dbsource': Source of the data or database from which the attack information was obtained.
#
# 'ransom': Indicates if a ransom was demanded or paid during a kidnapping-related attack.
#
# 'individual': Indicates if the attack was carried out by an individual acting alone (1) or a group (0).
#
# 'success': Indicates the overall success (1) or failure (0) of the terrorist attack.
#
# 'suicide': Indicates if the attack involved a suicide element (1) or not (0).
#
# 'hostkidoutcome_txt': Outcome of a hostage situation during the attack.
#
# 'ransomamt': Amount of ransom demanded or paid during a kidnapping-related attack.
#
# 'ishostkid': Indicates if there were hostages taken during the terrorist attack (1) or not (0).
#
# 'property': Indicates whether there was property damage during the terrorist attack (0 = no damage, 1 = property damage, -9 = unknown/missing data).
#
# Please note that this is not an exhaustive list of all the variables, but these are some of the key ones that provide essential information about each
# terrorism event in the dataset.

# %%
df.nunique()
# Out:
# eventid       181691
# iyear             47
# imonth            13
# iday              32
# approxdate      2244
#                ...
# INT_LOG            3
# INT_IDEO           3
# INT_MISC           3
# INT_ANY            3
# related        14306
# Length: 135, dtype: int64

# %%
df.nunique().sum()
# Out:
# 882952

# %%
df['iyear'].unique()
# Out:
# array([1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
#        1981, 1986, 1982, 1983, 1984, 1985, 1987, 1988, 1989, 1990, 1991,
#        1992, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017], dtype=int64)

# %%
df['imonth'].unique()
# Out:
# array([ 7,  0,  1,  2,  3,  4,  5,  6,  8,  9, 10, 11, 12], dtype=int64)

# %%
df['country_txt'].unique()
# Out:
# array(['Dominican Republic', 'Mexico', 'Philippines', 'Greece', 'Japan',
#        'United States', 'Uruguay', 'Italy', 'East Germany (GDR)',
#        'Ethiopia', 'Guatemala', 'Venezuela', 'West Germany (FRG)',
#        'Switzerland', 'Jordan', 'Spain', 'Brazil', 'Egypt', 'Argentina',
#        'Lebanon', 'Ireland', 'Turkey', 'Paraguay', 'Iran',
#        'United Kingdom', 'Colombia', 'Bolivia', 'Nicaragua',
#        'Netherlands', 'Belgium', 'Canada', 'Australia', 'Pakistan',
#        'Zambia', 'Sweden', 'Costa Rica', 'South Yemen', 'Cambodia',
#        'Israel', 'Poland', 'Taiwan', 'Panama', 'Kuwait',
#        'West Bank and Gaza Strip', 'Austria', 'Czechoslovakia', 'India',
#        'France', 'South Vietnam', 'Brunei', 'Zaire',
#        "People's Republic of the Congo", 'Portugal', 'Algeria',
#        'El Salvador', 'Thailand', 'Haiti', 'Sudan', 'Morocco', 'Cyprus',
#        'Myanmar', 'Afghanistan', 'Peru', 'Chile', 'Honduras',
#        'Yugoslavia', 'Ecuador', 'New Zealand', 'Malaysia', 'Singapore',
#        'Botswana', 'Jamaica', 'Chad', 'North Yemen', 'Andorra', 'Syria',
#        'South Korea', 'United Arab Emirates', 'South Africa', 'Kenya',
#        'Iraq', 'Somalia', 'Tanzania', 'Sri Lanka', 'Namibia', 'Bahamas',
#        'Nigeria', 'Barbados', 'Trinidad and Tobago', 'Bangladesh',
#        'Angola', 'Mauritania', 'Saudi Arabia', 'Djibouti', 'Indonesia',
#        'Malta', 'Rhodesia', 'Soviet Union', 'Denmark', 'Western Sahara',
#        'Guyana', 'Mozambique', 'Tunisia', 'Uganda', 'Norway', 'Lesotho',
#        'Gabon', 'Libya', 'Bahrain', 'Hong Kong', 'Senegal', 'Zimbabwe',
#        'Guinea', 'Grenada', 'New Hebrides', 'Belize', 'Guadeloupe',
#        'Martinique', 'Vatican City', 'Albania',
#        'Central African Republic', 'Seychelles', 'Dominica', 'Qatar',
#        'Bulgaria', 'Suriname', 'Swaziland', 'Luxembourg', 'Iceland',
#        'French Guiana', 'Falkland Islands', 'Burkina Faso',
#        'New Caledonia', 'Romania', 'Niger', 'Nepal', 'Togo', 'Finland',
#        'Fiji', 'Ghana', 'Maldives', 'Mauritius', 'Hungary', 'Laos',
#        'Papua New Guinea', 'China', 'Liberia', 'Republic of the Congo',
#        'Mali', 'Germany', 'Yemen', 'Rwanda', 'Sierra Leone', 'Cameroon',
#        'Cuba', 'Croatia', 'Georgia', 'Azerbaijan', 'Madagascar',
#        'Lithuania', 'Burundi', 'Ukraine', 'Moldova', 'Armenia', 'Russia',
#        'Ivory Coast', 'Kazakhstan', 'Antigua and Barbuda',
#        'Bosnia-Herzegovina', 'Equatorial Guinea', 'Tajikistan', 'Malawi',
#        'Uzbekistan', 'Latvia', 'Estonia', 'Vietnam', 'Comoros', 'Benin',
#        'Slovak Republic', 'Macedonia', 'Wallis and Futuna', 'Belarus',
#        'Czech Republic', 'Slovenia', 'Gambia', 'North Korea', 'Eritrea',
#        'St. Kitts and Nevis', 'French Polynesia', 'Macau', 'Kyrgyzstan',
#        'Vanuatu', 'Democratic Republic of the Congo', 'Kosovo',
#        'Solomon Islands', 'East Timor', 'St. Lucia', 'Guinea-Bissau',
#        'Montenegro', 'International', 'Turkmenistan', 'Serbia-Montenegro',
#        'Bhutan', 'Serbia', 'South Sudan'], dtype=object)

# %%
df['region_txt'].unique()
# Out:
# array(['Central America & Caribbean', 'North America', 'Southeast Asia',
#        'Western Europe', 'East Asia', 'South America', 'Eastern Europe',
#        'Sub-Saharan Africa', 'Middle East & North Africa',
#        'Australasia & Oceania', 'South Asia', 'Central Asia'],
#       dtype=object)

# %%
df['provstate'].unique()
# Out:
# array([nan, 'Federal', 'Tarlac', ..., 'Carlow', 'Western Lakes',
#        'Vidzeme'], dtype=object)

# %%
df['city'].unique()
# Out:
# array(['Santo Domingo', 'Mexico city', 'Unknown', ..., 'Hungrum',
#        'Ceelka Geelow', 'Kubentog'], dtype=object)

# %%
df['success'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df['suicide'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['attacktype1_txt'].unique()
# Out:
# array(['Assassination', 'Hostage Taking (Kidnapping)',
#        'Bombing/Explosion', 'Facility/Infrastructure Attack',
#        'Armed Assault', 'Hijacking', 'Unknown', 'Unarmed Assault',
#        'Hostage Taking (Barricade Incident)'], dtype=object)

# %%
df['targtype1_txt'].unique()
# Out:
# array(['Private Citizens & Property', 'Government (Diplomatic)',
#        'Journalists & Media', 'Police', 'Utilities', 'Military',
#        'Government (General)', 'Airports & Aircraft', 'Business',
#        'Educational Institution', 'Violent Political Party',
#        'Religious Figures/Institutions', 'Unknown', 'Transportation',
#        'Tourists', 'NGO', 'Telecommunication', 'Food or Water Supply',
#        'Terrorists/Non-State Militia', 'Other', 'Maritime',
#        'Abortion Related'], dtype=object)

# %%
df['gname'].unique()
# Out:
# array(['MANO-D', '23rd of September Communist League', 'Unknown', ...,
#        'Fatoni Warriors', 'Minorities of Metropolitan Attacks',
#        'Baloch Republican Party'], dtype=object)

# %%
df['nkill'].unique()
# Out:
# array([1.000e+00, 0.000e+00,       nan, 7.000e+00, 4.700e+01, 2.000e+00,
#        3.600e+01, 5.000e+00, 3.000e+00, 4.000e+00, 2.500e+01, 1.500e+01,
#        2.600e+01, 8.000e+00, 8.100e+01, 6.000e+00, 9.000e+00, 1.600e+01,
#        3.000e+01, 3.100e+01, 1.200e+01, 2.100e+01, 1.400e+01, 8.800e+01,
#        1.100e+01, 1.000e+01, 2.700e+01, 1.800e+01, 2.200e+01, 1.900e+01,
#        9.200e+01, 1.300e+01, 7.300e+01, 1.000e+02, 4.200e+01, 4.300e+01,
#        1.700e+01, 9.800e+01, 4.220e+02, 4.800e+01, 3.400e+01, 5.400e+01,
#        5.000e+01, 3.500e+01, 2.000e+01, 4.100e+01, 3.700e+01, 2.800e+01,
#        4.000e+01, 3.200e+01, 8.500e+01, 2.300e+01, 3.000e+02, 6.000e+01,
#        2.400e+01, 5.800e+01, 7.000e+01, 8.700e+01, 4.500e+01, 3.800e+01,
#        2.900e+01, 7.400e+01, 8.300e+01, 9.000e+01, 6.600e+01, 8.000e+01,
#        6.700e+01, 5.100e+01, 3.900e+01, 1.140e+02, 1.240e+02, 7.600e+01,
#        3.300e+01, 7.500e+01, 5.700e+01, 6.200e+01, 4.600e+01, 5.600e+01,
#        6.300e+01, 1.200e+02, 1.020e+02, 7.800e+01, 7.900e+01, 5.200e+01,
#        7.700e+01, 2.000e+02, 4.900e+01, 1.110e+02, 1.650e+02, 4.400e+01,
#        2.410e+02, 6.400e+01, 1.080e+02, 6.500e+01, 1.320e+02, 2.700e+02,
#        2.280e+02, 1.100e+02, 1.360e+02, 1.800e+02, 2.500e+02, 9.300e+01,
#        1.300e+02, 5.900e+01, 9.400e+01, 5.300e+01, 1.460e+02, 3.290e+02,
#        9.700e+01, 7.100e+01, 2.400e+02, 2.270e+02, 1.260e+02, 1.060e+02,
#        3.880e+02, 6.800e+01, 8.400e+01, 8.200e+01, 1.710e+02, 1.070e+02,
#        5.500e+01, 1.120e+02, 7.200e+01, 9.600e+01, 1.400e+02, 6.100e+01,
#        1.050e+02, 1.500e+02, 1.150e+02, 8.900e+01, 1.180e+03, 1.700e+02,
#        1.680e+02, 1.210e+02, 3.750e+02, 9.100e+01, 3.040e+02, 1.230e+02,
#        1.350e+02, 2.560e+02, 1.090e+02, 2.710e+02, 2.060e+02, 1.040e+02,
#        3.200e+02, 2.750e+02, 2.240e+02, 1.180e+02, 1.290e+02, 9.500e+01,
#        2.590e+02, 1.384e+03, 1.383e+03, 1.900e+02, 1.190e+02, 1.010e+02,
#        1.160e+02, 5.180e+02, 3.440e+02, 1.600e+02, 1.880e+02, 1.030e+02,
#        2.050e+02, 1.450e+02, 1.530e+02, 1.270e+02, 6.900e+01, 1.410e+02,
#        1.340e+02, 4.000e+02, 8.600e+01, 1.840e+02, 2.100e+02, 1.420e+02,
#        2.120e+02, 2.870e+02, 3.150e+02, 1.510e+02, 6.700e+02, 1.570e+03,
#        3.100e+02, 2.980e+02, 9.530e+02, 5.170e+02, 2.010e+02, 1.220e+02,
#        1.580e+02, 1.170e+02, 1.440e+02, 2.080e+02, 1.520e+02, 2.300e+02,
#        2.800e+02, 1.740e+02, 1.430e+02, 3.830e+02, 2.830e+02, 1.540e+02,
#        2.840e+02, 4.330e+02, 2.660e+02, 1.330e+02, 1.630e+02, 1.280e+02,
#        5.880e+02, 3.110e+02])

# %%
df['nwound'].unique()
# Out:
# array([0.000e+00,       nan, 1.000e+00, 2.000e+00, 7.000e+00, 9.000e+00,
#        1.700e+01, 5.000e+00, 3.000e+00, 1.000e+01, 1.200e+01, 2.000e+01,
#        4.000e+00, 1.100e+01, 2.700e+01, 1.300e+01, 1.900e+01, 1.300e+02,
#        5.600e+01, 2.400e+01, 6.000e+00, 7.200e+01, 2.380e+02, 5.500e+01,
#        1.500e+01, 8.000e+00, 1.800e+01, 5.000e+01, 3.400e+01, 1.400e+01,
#        7.000e+01, 1.020e+02, 4.100e+01, 4.800e+01, 3.600e+01, 2.500e+01,
#        8.100e+01, 5.400e+01, 5.300e+01, 1.000e+02, 4.500e+01, 3.300e+01,
#        4.000e+01, 6.200e+01, 7.400e+01, 2.200e+01, 3.100e+01, 1.600e+01,
#        3.000e+01, 2.850e+02, 2.300e+01, 4.200e+01, 4.300e+01, 7.600e+01,
#        4.400e+01, 5.200e+01, 4.600e+01, 4.900e+01, 1.600e+02, 3.700e+01,
#        2.100e+01, 6.000e+01, 7.800e+01, 2.600e+01, 2.800e+01, 3.900e+01,
#        3.800e+01, 3.500e+01, 3.200e+01, 8.000e+01, 4.700e+01, 1.880e+02,
#        2.150e+02, 8.500e+01, 7.500e+01, 1.610e+02, 9.000e+01, 3.000e+02,
#        9.500e+01, 1.350e+02, 6.100e+01, 1.380e+02, 7.100e+01, 7.000e+02,
#        6.600e+01, 1.360e+02, 1.200e+02, 2.170e+02, 3.190e+02, 1.330e+02,
#        6.800e+01, 7.300e+01, 2.900e+01, 7.510e+02, 2.000e+02, 1.120e+02,
#        2.500e+02, 8.200e+01, 1.320e+02, 2.300e+02, 1.070e+02, 1.140e+02,
#        8.400e+01, 1.400e+02, 1.500e+02, 9.600e+01, 5.100e+01, 5.800e+01,
#        6.400e+01, 2.950e+02, 1.060e+02, 1.250e+02, 6.900e+01, 5.900e+01,
#        5.700e+01, 1.220e+02, 1.090e+02, 8.800e+01, 1.150e+02, 1.760e+02,
#        2.200e+02, 9.700e+01, 6.500e+01, 8.000e+02, 1.730e+02, 9.200e+01,
#        5.000e+02, 2.360e+02, 9.800e+01, 2.860e+02, 1.410e+02, 5.500e+03,
#        6.500e+02, 6.710e+02, 8.600e+01, 1.040e+02, 8.300e+01, 1.010e+02,
#        1.272e+03, 1.050e+02, 3.860e+02, 3.910e+02, 1.100e+02, 1.490e+02,
#        8.900e+01, 9.100e+01, 1.190e+02, 7.700e+01, 1.180e+02, 6.700e+01,
#        1.700e+02, 1.940e+02, 1.920e+02, 2.270e+02, 2.600e+02, 4.000e+03,
#        1.800e+02, 1.840e+02, 9.900e+01, 9.400e+01, 1.370e+02, 8.190e+03,
#        8.191e+03, 1.710e+02, 1.210e+02, 1.030e+02, 1.620e+02, 1.970e+02,
#        1.510e+02, 2.240e+02, 1.340e+02, 2.330e+02, 1.670e+02, 4.500e+02,
#        2.160e+02, 1.450e+02, 6.300e+01, 7.270e+02, 1.820e+02, 1.590e+02,
#        1.080e+02, 1.280e+02, 3.400e+02, 1.630e+02, 5.420e+02, 8.700e+01,
#        1.550e+02, 8.170e+02, 2.570e+02, 1.480e+02, 1.230e+02, 2.460e+02,
#        1.270e+02, 3.470e+02, 1.780e+02, 1.680e+02, 2.070e+02, 1.830e+02,
#        1.170e+02, 7.500e+02, 1.470e+02, 1.001e+03, 9.300e+01, 1.540e+02,
#        2.350e+02, 1.580e+02, 2.110e+02, 1.160e+02, 2.760e+02, 5.520e+02,
#        3.600e+02, 1.130e+02, 1.570e+02, 1.750e+02, 3.010e+02, 1.310e+02,
#        4.000e+02, 3.700e+02, 8.500e+00, 1.690e+02, 2.010e+02, 1.110e+02,
#        1.430e+02, 1.530e+02, 1.240e+02, 7.900e+01, 2.700e+02, 1.520e+02,
#        2.960e+02, 2.450e+02, 1.500e+03, 3.510e+02, 6.000e+02, 4.330e+02,
#        1.770e+02, 4.910e+02, 4.050e+02, 8.510e+02, 3.160e+02])

# %%
df['property'].unique()
# Out:
# array([ 0,  1, -9], dtype=int64)

# %%
df['hostkidoutcome_txt'].unique()
# Out:
# array([nan, 'Hostage(s) released by perpetrators', 'Successful Rescue',
#        'Hostage(s) killed (not during rescue attempt)',
#        'Hostage(s) escaped (not during rescue attempt)', 'Unknown',
#        'Combination', 'Attempted Rescue'], dtype=object)

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.drop(columns=['location', 'summary', 'alternative', 'attacktype2','targtype1',
    'attacktype2_txt', 'attacktype3', 'attacktype3_txt', 'targsubtype1',
    'corp1', 'target1', 'natlty1', 'targtype2', 'targtype2_txt',
    'targsubtype2', 'targsubtype2_txt', 'corp2', 'target2', 'natlty2', 'natlty2_txt',
    'targtype3', 'targtype3_txt', 'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3',
    'natlty3', 'natlty3_txt', 'gsubname', 'gname2', 'gsubname2', 'gname3', 'gsubname3',
    'motive', 'claimmode', 'claimmode_txt', 'claim2', 'claimmode2', 'claimmode2_txt',
    'claim3', 'claimmode3', 'claimmode3_txt', 'compclaim', 'weapsubtype1',
    'weaptype2', 'weaptype2_txt', 'weapsubtype2', 'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt',
    'weapsubtype3', 'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4', 'weapsubtype4_txt',
    'weapdetail', 'nkillus', 'nkillter', 'nwoundus', 'nwoundte', 'propextent', 'propextent_txt',
    'propvalue', 'propcomment', 'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert', 'kidhijcountry',
    'ransomamt', 'ransomamtus', 'ransompaid', 'ransompaidus', 'ransomnote', 'hostkidoutcome', 'hostkidoutcome_txt',
    'nreleased', 'addnotes', 'scite1', 'scite2', 'scite3', 'related','approxdate','extended','country','region','specificity','vicinity','crit1', 'crit2', 'crit3', 'doubtterr','multiple','natlty1_txt','guncertain1', 'guncertain2', 'guncertain3','nperps',
       'nperpcap','INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY','attacktype1','property','weaptype1','resolution'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (181691, 26)

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'country_txt', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'alternative_txt',
#        'success', 'suicide', 'attacktype1_txt', 'targtype1_txt',
#        'targsubtype1_txt', 'gname', 'individual', 'claimed', 'weaptype1_txt',
#        'weapsubtype1_txt', 'nkill', 'nwound', 'ishostkid', 'ransom',
#        'dbsource'],
#       dtype='object')

# %%
df.rename(columns={'eventid':'Event_ID','iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country',
       'region_txt':'Region', 'provstate':'Province_State', 'city':'City', 'latitude':'Latitude', 'longitude':'Longitude',
       'alternative_txt':'Alternative_Description', 'success':'Success', 'suicide':'Suicide', 'attacktype1_txt':'Attack_Type',
       'targtype1_txt':'Target_Type_Description', 'targsubtype1_txt':'Target_Subtype_Description', 'gname':'Group_Name', 'individual':'Individual_Attack', 'claimed':'Claimed',
       'weaptype1_txt':'Weapon_Type', 'weapsubtype1_txt':'Weapon_Subtype', 'nkill':'Fatalities', 'nwound':'Injured', 'ishostkid':'Hostages',
       'ransom':'Ransom', 'dbsource':'Data_Source'},inplace=True)

# %%
df.columns
# Out:
# Index(['Event_ID', 'Year', 'Month', 'Day', 'Country', 'Region',
#        'Province_State', 'City', 'Latitude', 'Longitude',
#        'Alternative_Description', 'Success', 'Suicide', 'Attack_Type',
#        'Target_Type_Description', 'Target_Subtype_Description', 'Group_Name',
#        'Individual_Attack', 'Claimed', 'Weapon_Type', 'Weapon_Subtype',
#        'Fatalities', 'Injured', 'Hostages', 'Ransom', 'Data_Source'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Event_ID                    181691 non-null  int64
#  1   Year                        181691 non-null  int64
#  2   Month                       181691 non-null  int64
#  3   Day                         181691 non-null  int64
#  4   Country                     181691 non-null  object
#  5   Region                      181691 non-null  object
#  6   Province_State              181270 non-null  object
#  7   City                        181256 non-null  object
#  8   Latitude                    177135 non-null  float64
#  9   Longitude                   177134 non-null  float64
#  10  Alternative_Description     29011 non-null   object
#  11  Success                     181691 non-null  int64
#  12  Suicide                     181691 non-null  int64
#  13  Attack_Type                 181691 non-null  object
#  14  Target_Type_Description     181691 non-null  object
#  15  Target_Subtype_Description  171318 non-null  object
#  16  Group_Name                  181691 non-null  object
#  17  Individual_Attack           181691 non-null  int64
#  18  Claimed                     115571 non-null  float64
#  19  Weapon_Type                 181691 non-null  object
#  20  Weapon_Subtype              160923 non-null  object
#  21  Fatalities                  171378 non-null  float64
#  22  Injured                     165380 non-null  float64
#  23  Hostages                    181513 non-null  float64
#  24  Ransom                      77381 non-null   float64
#  25  Data_Source                 181691 non-null  object
# dtypes: float64(7), int64(7), object(12)
# memory usage: 36.0+ MB

# %%
columns_to_change = ['Success', 'Suicide', 'Individual_Attack', 'Claimed', 'Fatalities', 'Injured', 'Hostages', 'Ransom']  
df[columns_to_change] = df[columns_to_change].astype('object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Event_ID                    181691 non-null  int64
#  1   Year                        181691 non-null  int64
#  2   Month                       181691 non-null  int64
#  3   Day                         181691 non-null  int64
#  4   Country                     181691 non-null  object
#  5   Region                      181691 non-null  object
#  6   Province_State              181270 non-null  object
#  7   City                        181256 non-null  object
#  8   Latitude                    177135 non-null  float64
#  9   Longitude                   177134 non-null  float64
#  10  Alternative_Description     29011 non-null   object
#  11  Success                     181691 non-null  object
#  12  Suicide                     181691 non-null  object
#  13  Attack_Type                 181691 non-null  object
#  14  Target_Type_Description     181691 non-null  object
#  15  Target_Subtype_Description  171318 non-null  object
#  16  Group_Name                  181691 non-null  object
#  17  Individual_Attack           181691 non-null  object
#  18  Claimed                     115571 non-null  object
#  19  Weapon_Type                 181691 non-null  object
#  20  Weapon_Subtype              160923 non-null  object
#  21  Fatalities                  171378 non-null  object
#  22  Injured                     165380 non-null  object
#  23  Hostages                    181513 non-null  object
#  24  Ransom                      77381 non-null   object
#  25  Data_Source                 181691 non-null  object
# dtypes: float64(2), int64(4), object(20)
# memory usage: 36.0+ MB

# %%
columns_to_fill = ['Province_State','City','Longitude','Latitude', 'Alternative_Description', 'Target_Subtype_Description', 'Claimed', 'Weapon_Subtype', 'Fatalities', 'Injured', 'Hostages', 'Ransom']
df[columns_to_fill] = df[columns_to_fill].fillna('Unknown')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Event_ID                    181691 non-null  int64
#  1   Year                        181691 non-null  int64
#  2   Month                       181691 non-null  int64
#  3   Day                         181691 non-null  int64
#  4   Country                     181691 non-null  object
#  5   Region                      181691 non-null  object
#  6   Province_State              181691 non-null  object
#  7   City                        181691 non-null  object
#  8   Latitude                    181691 non-null  object
#  9   Longitude                   181691 non-null  object
#  10  Alternative_Description     181691 non-null  object
#  11  Success                     181691 non-null  object
#  12  Suicide                     181691 non-null  object
#  13  Attack_Type                 181691 non-null  object
#  14  Target_Type_Description     181691 non-null  object
#  15  Target_Subtype_Description  181691 non-null  object
#  16  Group_Name                  181691 non-null  object
#  17  Individual_Attack           181691 non-null  object
#  18  Claimed                     181691 non-null  object
#  19  Weapon_Type                 181691 non-null  object
#  20  Weapon_Subtype              181691 non-null  object
#  21  Fatalities                  181691 non-null  object
#  22  Injured                     181691 non-null  object
#  23  Hostages                    181691 non-null  object
#  24  Ransom                      181691 non-null  object
#  25  Data_Source                 181691 non-null  object
# dtypes: int64(4), object(22)
# memory usage: 36.0+ MB

# %%
df['Success'].value_counts()
# Out:
# Success
# 1    161632
# 0     20059
# Name: count, dtype: int64

# %%
df['Success'] = df['Success'].replace({1: 'Yes', 0: 'No'})

# %%
df['Success'].value_counts()
# Out:
# Success
# Yes    161632
# No      20059
# Name: count, dtype: int64

# %%
df['Suicide'].value_counts()
# Out:
# Suicide
# 0    175058
# 1      6633
# Name: count, dtype: int64

# %%
suicide_mapping = {
    0: 'No Suicide',
    1: 'Suicide Involved'
}

df['Suicide'] = df['Suicide'].replace(suicide_mapping)

# %%
df['Suicide'].value_counts()
# Out:
# Suicide
# No Suicide          175058
# Suicide Involved      6633
# Name: count, dtype: int64

# %%
df['Claimed'].unique()
# Out:
# array(['Unknown', 0.0, 1.0, -9.0], dtype=object)

# %%
claimed_mapping = {
    0.0: 'Claimed',
    1.0: 'Not Claimed',
    'Unknown':'Claim Data Unavailable',
    -9.0: 'Claim Data Unavailable'
}

df['Claimed'] = df['Claimed'].replace(claimed_mapping)

# %%
df['Claimed'].unique()
# Out:
# array(['Claim Data Unavailable', 'Claimed', 'Not Claimed'], dtype=object)

# %%
df['Hostages'].unique()
# Out:
# array([0.0, 1.0, 'Unknown', -9.0], dtype=object)

# %%
hostages_mapping = {
    0.0: 'No Hostages',
    1.0: 'Hostages Taken',
    'Unknown': 'Hostages Data Unavailable',
    -9.0: 'Hostages Data Unavailable'
}

df['Hostages'] = df['Hostages'].replace(hostages_mapping)

# %%
df['Hostages'].unique()
# Out:
# array(['No Hostages', 'Hostages Taken', 'Hostages Data Unavailable'],
#       dtype=object)

# %%
df['Ransom'].value_counts()
# Out:
# Ransom
#  Unknown    104310
#  0.0         74684
# -9.0          1398
#  1.0          1299
# Name: count, dtype: int64

# %%
ransom_mapping = {
    'Unknown': 'Ransom Status Unavailable',
    0.0: 'No Ransom',
    -9.0: 'Ransom Data Unavailable',
    1.0: 'Ransom Data Unavailable'
}

df['Ransom'] = df['Ransom'].replace(ransom_mapping)

# %%
mode_month = df['Month'].mode().values[0]

# %%
df['Month'] = df['Month'].replace(0, mode_month)

# %%
Four_decades=df['Year'].value_counts().sort_index()            #getting the value counts
Four_decades
# Out:
# Year
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581
# 1975      740
# 1976      923
# 1977     1319
# 1978     1526
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 1983     2870
# 1984     3495
# 1985     2915
# 1986     2860
# 1987     3183
# 1988     3721
# 1989     4324
# 1990     3887
# 1991     4683
# 1992     5071
# 1994     3456
# 1995     3081
# 1996     3058
# 1997     3197
# 1998      934
# 1999     1395
# 2000     1814
# 2001     1906
# 2002     1333
# 2003     1278
# 2004     1166
# 2005     2017
# 2006     2758
# 2007     3242
# 2008     4805
# 2009     4721
# 2010     4826
# 2011     5076
# 2012     8522
# 2013    12036
# 2014    16903
# 2015    14965
# 2016    13587
# 2017    10900
# Name: count, dtype: int64

# %%
four_decades = df['Year'].value_counts().sort_index()

# line plot
plt.figure(figsize=(10, 6))
plt.plot(four_decades.index, four_decades.values, marker='o', linestyle='-', color='b')
plt.title('Temporal Trends in Global Terrorism (Last Four Decades)')
plt.xlabel('Year')
plt.ylabel('Number of Incidents')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
Region_terror=df['Region'].value_counts()                   
Region_terror
# Out:
# Region
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: count, dtype: int64

# %%
labels = Region_terror.index
sizes = Region_terror.values

# Horizontal bar chart
plt.figure(figsize=(10, 8))
plt.barh(labels, sizes, color='skyblue')
plt.xlabel('Number of Incidents')
plt.ylabel('Region')
plt.title('Distribution of Terrorist Attacks by Region')
plt.show()

# %%
top_countries=df['Country'].value_counts().head(10) 
top_countries
# Out:
# Country
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: count, dtype: int64

# %%
Bottom_countries=df['Country'].value_counts().tail(10)   
Bottom_countries
# Out:
# Country
# Vatican City           1
# Falkland Islands       1
# St. Lucia              1
# North Korea            1
# New Hebrides           1
# International          1
# Wallis and Futuna      1
# South Vietnam          1
# Andorra                1
# Antigua and Barbuda    1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 5))
top_countries.plot(kind='bar')
plt.title('Top Countries with Highest Frequency of Terrorist Attacks')
plt.xlabel('Country')
plt.ylabel('Number of Incidents')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df['City'].value_counts().head(10)
# Out:
# City
# Unknown         10210
# Baghdad          7589
# Karachi          2652
# Lima             2359
# Mosul            2265
# Belfast          2171
# Santiago         1621
# Mogadishu        1581
# San Salvador     1558
# Istanbul         1048
# Name: count, dtype: int64

# %%
city_counts = {
    'Baghdad': 7589,
    'Karachi': 2652,
    'Lima': 2359,
    'Mosul': 2265,
    'Belfast': 2171,
    'Santiago': 1621,
    'Mogadishu': 1581,
    'San Salvador': 1558,
    'Istanbul': 1048
}

cities = list(city_counts.keys())
attack_counts = list(city_counts.values())

plt.figure(figsize=(10, 10))
plt.pie(attack_counts, labels=cities, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Distribution of Terrorist Attacks in Top Cities')
plt.axis('equal')
plt.show()

# %%
common_attack_types=df['Attack_Type'].value_counts().head()
common_attack_types
# Out:
# Attack_Type
# Bombing/Explosion                 88255
# Armed Assault                     42669
# Assassination                     19312
# Hostage Taking (Kidnapping)       11158
# Facility/Infrastructure Attack    10356
# Name: count, dtype: int64

# %%
common_attack_types = df['Attack_Type'].value_counts().head()
plt.figure(figsize=(10, 6))
common_attack_types.plot(kind='bar', color='skyblue')
plt.xlabel('Attack Type')
plt.ylabel('Frequency')
plt.title('Most Common Types of Terrorist Tactics')
plt.xticks(rotation=40) 
plt.show()

# %%
df['Month'].value_counts()
# Out:
# Month
# 5     16895
# 7     16268
# 8     15800
# 10    15563
# 6     15359
# 3     15257
# 4     15152
# 1     14936
# 11    14906
# 9     14180
# 2     13879
# 12    13496
# Name: count, dtype: int64

# %%
month_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']


attack_counts = [14936, 13879, 15257, 15152, 16895, 15359, 16268, 15800, 14180, 15563, 14906, 13496]

plt.figure(figsize=(10, 6))
plt.plot(month_names, attack_counts, marker='o', color='skyblue')
plt.xlabel('Month')
plt.ylabel('Frequency')
plt.title('Terrorist Activity by Month')
plt.xticks(rotation=40) 
plt.show()

# %%
plt.figure(figsize=(15, 9))
attack_patterns = df.groupby(['Year', 'Region']).size().unstack()

# Plotting each region's attack pattern using a line plot
for region in attack_patterns.columns:
    plt.plot(attack_patterns.index, attack_patterns[region], label=region)

plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.title('Terrorist Attack Patterns Over Time in Different Regions')
plt.legend()
plt.grid()
plt.show()

# %%
attack_type_region_freq = df.groupby(['Attack_Type', 'Region']).size().reset_index(name='Frequency')
print(attack_type_region_freq)
# Out:
#        Attack_Type                       Region  Frequency
# 0    Armed Assault        Australasia & Oceania         51
# 1    Armed Assault  Central America & Caribbean       4361
# 2    Armed Assault                 Central Asia        116
# 3    Armed Assault                    East Asia        117
# 4    Armed Assault               Eastern Europe       1274
# ..             ...                          ...        ...
# 103        Unknown                South America        754
# 104        Unknown                   South Asia       2021
# 105        Unknown               Southeast Asia        433
# 106        Unknown           Sub-Saharan Africa       1355
# 107        Unknown               Western Europe        265
#
# [108 rows x 3 columns]

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(15, 7))

filtered_df = df[df['Attack_Type'] != 'Unknown']
sns.countplot(data=filtered_df, x='Attack_Type', hue='Region', order=filtered_df['Attack_Type'].value_counts().index)
plt.xticks(rotation=45)
plt.xlabel('Attack Type')
plt.ylabel('Frequency')
plt.title('Frequency of Attack Types across Regions')
plt.legend(title='Region')
plt.show()

# %%
Primary_target_type=df['Target_Type_Description'].value_counts()
Primary_target_type
# Out:
# Target_Type_Description
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15, 6))
Primary_target_type.plot(kind='bar', color='skyblue')
plt.xlabel('Frequency')
plt.ylabel('Target Type')
plt.title('Frequency of Target Types')
plt.show()

# %%
df['Weapon_Type'].value_counts()
# Out:
# Weapon_Type
# Explosives                                                                     92426
# Firearms                                                                       58524
# Unknown                                                                        15157
# Incendiary                                                                     11135
# Melee                                                                           3655
# Chemical                                                                         321
# Sabotage Equipment                                                               141
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)      136
# Other                                                                            114
# Biological                                                                        35
# Fake Weapons                                                                      33
# Radiological                                                                      14
# Name: count, dtype: int64

# %%
Frequent_weapon=df[df['Weapon_Type'] != 'Unknown']
x=Frequent_weapon['Weapon_Type'].value_counts()
x
# Out:
# Weapon_Type
# Explosives                                                                     92426
# Firearms                                                                       58524
# Incendiary                                                                     11135
# Melee                                                                           3655
# Chemical                                                                         321
# Sabotage Equipment                                                               141
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)      136
# Other                                                                            114
# Biological                                                                        35
# Fake Weapons                                                                      33
# Radiological                                                                      14
# Name: count, dtype: int64

# %%
data = {
    'Weapon_Type': ['Explosives', 'Firearms', 'Incendiary', 'Melee', 'Chemical', 'Sabotage Equipment',
                    'Vehicle', 'Other',
                    'Biological', 'Fake Weapons', 'Radiological'],
    'Count': [92426, 58524, 11135, 3655, 321, 141, 136, 114, 35, 33, 14]
}


# Create a DataFrame
df1 = pd.DataFrame(data)

sns.set(style="whitegrid")

# Create a bar plot using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='Weapon_Type', y='Count', data=df1, color='skyblue')
plt.title('Weapon Types in Global Terrorism')
plt.xlabel('Weapon Type')
plt.ylabel('Number of Incidents')
plt.xticks(rotation=45, ha='right')

for index, row in df1.iterrows():
    plt.text(index, row['Count'] + 1000, str(row['Count']), ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

# %%
pivot_table = pd.crosstab(
    df['Target_Type_Description'],
    df['Attack_Type']
)

plt.figure(figsize=(12, 8))

pivot_table.plot(kind='bar', figsize=(15, 7))
plt.xlabel('Target Type')
plt.ylabel('Count')
plt.title('Correlation between Target Types and Attack Types')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Attack Type')
plt.tight_layout()
plt.show()

# %%
df[df['Group_Name'] != 'Unknown']['Group_Name'].value_counts().head(5)
# Out:
# Group_Name
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# Name: count, dtype: int64

# %%
top_groups = df[df['Group_Name'] != 'Unknown']['Group_Name'].value_counts().head(5)
plt.figure(figsize=(8, 8))
plt.pie(top_groups, labels=top_groups.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Top 5 Terrorist Groups (Excluding "Unknown")')
plt.show()

# %%
success_rate=df['Success'].value_counts()
success_rate
# Out:
# Success
# Yes    161632
# No      20059
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 6))
success_rate.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=['brown', 'red'])
plt.title('Proportion of Successful vs. Failed Terrorist Attacks')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
numeric_df = df.select_dtypes(include=[np.number])
correlation_matrix = numeric_df.corr()
print(correlation_matrix)
# Out:
#           Event_ID      Year     Month       Day
# Event_ID  1.000000  0.999996  0.002389  0.018336
# Year      0.999996  1.000000 -0.000178  0.018254
# Month     0.002389 -0.000178  1.000000  0.005212
# Day       0.018336  0.018254  0.005212  1.000000

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# Based on the insights derived from the Global Terrorism Database (GTD) analysis, here are some recommendations for the client to achieve their business objectives:
#
# Targeted Security Measures: Implement enhanced security measures in regions with a high frequency of terrorist incidents, such as the Middle East & North Africa and South Asia, while remaining vigilant in areas with lower incident counts.
#
# Strategic Resource Allocation: Allocate resources and strategies based on the prevalent terrorist tactics, with a particular focus on countering bombings/explosions, armed assaults, and assassinations.
#
# Seasonal Preparedness: Recognize and prepare for potential seasonal trends in terrorist activity, ensuring heightened vigilance during months like May, July, and August while also addressing the underlying reasons behind these patterns.
#
# Cyclical Analysis: Further investigate the cyclic patterns observed in the temporal distribution of attacks, identifying the factors driving these cycles and using the insights to enhance counterterrorism strategies.
#
# Global Collaboration: Collaborate with international organizations and governments to address the concentrated nature of terrorist incidents in certain cities and regions, encouraging information sharing and coordinated efforts.
#
# Localized Measures: Tailor security strategies to address the specific target types prevalent in each region, adapting approaches to protect private citizens, military personnel, and police forces.
#
# Targeted Counter-Radicalization: Leverage insights from the most active terrorist groups to design targeted counter-radicalization initiatives aimed at discouraging individuals from joining organizations like the Taliban, ISIL, and Al-Shabaab.
#
# Success-Failure Analysis: Investigate the reasons behind the relatively higher success rate of terrorist attacks and focus on strategies that can disrupt the planning and execution of attacks, leading to a higher percentage of failures.
#
# Long-Term Patterns: Analyze the extended timeframe of terrorism trends to identify historical turning points and correlate them with geopolitical events, enabling a deeper understanding of the impact of global dynamics on terrorism.
#
# Risk Management for Businesses: Provide businesses operating in regions with higher terrorism risks with data-driven risk management strategies, facilitating informed decisions for their operations.
#
# Public Awareness Campaigns: Utilize the findings to create impactful public awareness campaigns that educate the general population about terrorism's complexities and the need for ongoing efforts to combat it.
#
# Policy Recommendations: Collaborate with policymakers to develop evidence-based counterterrorism policies, utilizing the insights to address the vulnerabilities in high-impact regions and refine existing strategies.
#
# Continuous Evaluation: Establish a framework for evaluating the effectiveness of counterterrorism efforts, ensuring a continuous feedback loop to refine strategies and adapt to evolving threat landscapes.
#
# International Research Collaboration: Foster collaboration with the global research community by sharing insights and analysis from the GTD, contributing to a comprehensive understanding of terrorism's multifaceted nature.
#
# Holistic Approach: Recognize the interconnectedness of terrorism with global events, socio-political dynamics, and regional challenges, advocating for a holistic approach that considers all these factors in counterterrorism strategies.

# %% [markdown]
# **Conclusion**

# %% [markdown]
# In conclusion, the analysis of the Global Terrorism Database (GTD) offers profound insights into the intricate world of terrorism, shedding light on patterns, trends, and correlations that have far-reaching implications for security, policy-making, and global collaboration. The comprehensive examination of the data has provided actionable recommendations for achieving the outlined business objectives.The analysis underscores the urgency of targeted security measures in regions with high incident frequencies, emphasizing the need for adaptable strategies that align with prevalent terrorist tactics. The identification of seasonal and cyclical patterns offers a valuable tool for anticipating and preparing for potential spikes in terrorist activity, while localized insights guide efforts to safeguard vulnerable target types. Moreover, the revelation of key terrorist groups and their activities serves as a foundation for tailored counter-radicalization initiatives, contributing to the broader goal of preventing recruitment and radicalization. The success-failure analysis highlights the significance of disruption in attack planning, further motivating resource allocation and collaboration to thwart future incidents. This analysis also underscores the importance of international cooperation in counterterrorism. By sharing knowledge, insights, and strategies, countries can collectively address the concentrated nature of incidents in specific cities and regions, fostering a global network committed to combating terrorism's evolving challenges.
#
# As we reflect on the insights derived from the GTD analysis, it's evident that addressing terrorism demands a multi-faceted approach that accounts for historical, seasonal, and cyclical dynamics. By embracing data-driven decision-making, fostering collaboration, and prioritizing the safety of citizens and organizations, the pursuit of the outlined business objectives stands poised to contribute significantly to a safer and more secure global landscape. The complexities revealed by this analysis reinforce the need for continuous evaluation, adaptable strategies, and a commitment to countering terrorism through holistic and informed efforts.
